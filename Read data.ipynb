# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Application  Dup             IdTT                             MessageId  \
# 0    SMSC_VAM    0  INC000001826242  68564c44-ee7e-71e7-05c4-0a1f2e4c0000
# 1    SMSC_VAM    0  INC000001826242  685666f2-ee7e-71e7-05c4-0a1f2e4c0000
# 2    SMSC_VAM    0  INC000001826242  685657e8-ee7e-71e7-05c4-0a1f2e4c0000
# 3    SMSC_VAM    0  INC000001826242  685673ea-ee7e-71e7-05c4-0a1f2e4c0000
# 4      Radius    0                   79aab5d4-ee7e-71e7-08f0-0a1c567b0000
#
#                                          MessageText MsgGroup  \
# 0  VAM-FW-001  00 00 14646 [ERROR] main hp.smsc.c...     MVNO
# 1  VAM-FW-001  00 00 15025 [ERROR] main hp.smsc.c...     MVNO
# 2  VAM-FW-001  00 00 14648 [ERROR] main hp.smsc.c...     MVNO
# 3  VAM-FW-001  00 00 15027 [ERROR] main hp.smsc.c...     MVNO
# 4  OTW-FW-001  AAAMotive certificateExpiredHttp-C...       OS
#
#                       Node                                             Object  \
# ...

# %%
applications = df_data_1.groupby('Application').size()
print(applications)
# Out:
# Application
#                           101
# AAS                         6
# ACB                       268
# AMU                        11
# AOL_INT                     2
# AOL_INT2                    1
# AOL_PRE                    78
# AOL_PRO                     8
# APM_PRO                     9
# APOCAPRO                    8
# BFV_PRE                     2
# BFV_PRO                    18
# BMP                        32
# BSB_PRE                     5
# BSB_PRO                    31
# BTM_PRE                     8
# CACTI                       2
# CAP_PRO                    20
# CBK-DATI-SITO              10
# CCS                        53
# CCS-MSAN                   56
# CDN                       368
# CDN_GW                    144
# CDV_PRE                    27
# CDV_PRO                     1
# CMC_PRO                    13
# CMMCDEV                     3
# CMMCINT                     1
# CMMCINT2                    3
# CMMCPRE                     6
# ...

# %%
def has_ticket(event):
    """
    Check if an event generated a ticket    
    return True if it does, False otherwise
    """
    return (event['IdTT'] is not '')

df_data_1['HasTicket'] = df_data_1.apply(has_ticket, axis='columns');
df_data_1.head()
# Out:
#   Application  Dup             IdTT                             MessageId  \
# 0    SMSC_VAM    0  INC000001826242  68564c44-ee7e-71e7-05c4-0a1f2e4c0000
# 1    SMSC_VAM    0  INC000001826242  685666f2-ee7e-71e7-05c4-0a1f2e4c0000
# 2    SMSC_VAM    0  INC000001826242  685657e8-ee7e-71e7-05c4-0a1f2e4c0000
# 3    SMSC_VAM    0  INC000001826242  685673ea-ee7e-71e7-05c4-0a1f2e4c0000
# 4      Radius    0                   79aab5d4-ee7e-71e7-08f0-0a1c567b0000
#
#                                          MessageText MsgGroup  \
# 0  VAM-FW-001  00 00 14646 [ERROR] main hp.smsc.c...     MVNO
# 1  VAM-FW-001  00 00 15025 [ERROR] main hp.smsc.c...     MVNO
# 2  VAM-FW-001  00 00 14648 [ERROR] main hp.smsc.c...     MVNO
# 3  VAM-FW-001  00 00 15027 [ERROR] main hp.smsc.c...     MVNO
# 4  OTW-FW-001  AAAMotive certificateExpiredHttp-C...       OS
#
#                       Node                                             Object  \
# ...
